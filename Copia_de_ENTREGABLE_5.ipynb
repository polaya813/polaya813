# %% [markdown]
# <a href="https://colab.research.google.com/github/polaya813/polaya813/blob/main/Copia_de_ENTREGABLE_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DESARROLLO DE LOS PUNTOS DEL ENTREGABLE 5

# %% [markdown]
# Importar librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io
from scipy import stats # Opcional, pandas .skew() y .kurt() son suficientes
# Configuraciones opcionales para mejor visualización
plt.style.use('seaborn-v0_8-whitegrid') # Estilo de gráficos
pd.set_option('display.max_columns', None) # Mostrar todas las columnas

pd.set_option('display.float_format', lambda x: '%.2f' % x) # Formato de flotantes

print("Librerías importadas.")
# Out:
# Librerías importadas.

# %% [markdown]
# # Exploración inicial del dataset

# %%
# Carga del dataset desde una URL
dataset_url = "https://raw.githubusercontent.com/reginatwopointo/Life-Expectancy-Exploratory-Data-Analysis-and-Visualization/main/Life%20Expectancy%20Data.csv"
df_life = pd.read_csv(dataset_url)

# %% [markdown]
# ## Exploracion inicial del dataset

# %%
# Mostrar primeras n lineas del dataset
df_life.head(5)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.00              263
# 1  Afghanistan  2014  Developing             59.90              271
# 2  Afghanistan  2013  Developing             59.90              268
# 3  Afghanistan  2012  Developing             59.50              272
# 4  Afghanistan  2011  Developing             59.20              275
#
#    infant deaths  Alcohol percentage expenditure  Hepatitis B  Measles   \
# 0             62     0.01            71.27962362        65.00      1154
# 1             64     0.01            73.52358168        62.00       492
# 2             66     0.01            73.21924272        64.00       430
# 3             69     0.01             78.1842153        67.00      2787
# 4             71     0.01            7.097108703        68.00      3013
#
#     BMI   under-five deaths   Polio  Total expenditure  Diphtheria   \
# ...

# %%
# Mostrar ultimas n lineas del dataset
df_life.tail(5)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2875  Zimbabwe  2004  Developing             44.30              723
# 2876  Zimbabwe  2003  Developing             44.50              715
# 2877  Zimbabwe  2002  Developing             44.80               73
# 2878  Zimbabwe  2001  Developing             45.30              686
# 2879  Zimbabwe  2000  Developing             46.00              665
#
#       infant deaths  Alcohol percentage expenditure  Hepatitis B  Measles   \
# 2875             27     4.36                      0        68.00        31
# 2876             26     4.06                      0         7.00       998
# 2877             25     4.43                      0        73.00       304
# 2878             25     1.72                      0        76.00       529
# 2879             24     1.68                      0        79.00      1483
#
#        BMI   under-five deaths   Polio  Total expenditure  Diphtheria   \
# ...

# %%
# Información general del Dataframe
df_life.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2880 entries, 0 to 2879
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2880 non-null   object
#  1   Year                             2880 non-null   int64
#  2   Status                           2880 non-null   object
#  3   Life expectancy                  2880 non-null   float64
#  4   Adult Mortality                  2880 non-null   int64
#  5   infant deaths                    2880 non-null   int64
#  6   Alcohol                          2842 non-null   float64
#  7   percentage expenditure           2880 non-null   object
#  8   Hepatitis B                      2539 non-null   float64
#  9   Measles                          2880 non-null   int64
#  10   BMI                             2864 non-null   float64
#  11  under-five deaths                2880 non-null   int64
# ...

# %%
# Obtener las estadísticas descriptivas
df_life.describe(include='all')
# Out:
#             Country    Year      Status  Life expectancy   Adult Mortality  \
# count          2880 2880.00        2880           2880.00          2880.00
# unique          180     NaN           2               NaN              NaN
# top     Afghanistan     NaN  Developing               NaN              NaN
# freq             16     NaN        2368               NaN              NaN
# mean            NaN 2007.50         NaN             69.37           164.58
# std             NaN    4.61         NaN              9.45           123.37
# min             NaN 2000.00         NaN             36.30             1.00
# 25%             NaN 2003.75         NaN             63.48            75.00
# 50%             NaN 2007.50         NaN             72.10           144.00
# 75%             NaN 2011.25         NaN             75.80           226.00
# max             NaN 2015.00         NaN             89.00           723.00
#
# ...

# %%
# Dimensiones del dataframe
# (filas, columnas)
df_life.shape
# Out:
# (2880, 22)

# %% [markdown]
# # Limpieza y Preparación de datos

# %% [markdown]
# ### Renombrar Columnas

# %%
# Columnas sin estandarizar
df_life.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
# Renombrar Columnas

df_life.columns = df_life.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('-', '_')

# %%
df_life.columns
# Out:
# Index(['country', 'year', 'status', 'life_expectancy', 'adult_mortality',
#        'infant_deaths', 'alcohol', 'percentage_expenditure', 'hepatitis_b',
#        'measles', 'bmi', 'under_five_deaths', 'polio', 'total_expenditure',
#        'diphtheria', 'hiv/aids', 'gdp', 'population', 'thinness__1_19_years',
#        'thinness_5_9_years', 'income_composition_of_resources', 'schooling'],
#       dtype='object')

# %%
# Ver primera n columnas

df_life.columns[:5]
# Out:
# Index(['country', 'year', 'status', 'life_expectancy', 'adult_mortality'], dtype='object')

# %% [markdown]
# ### Manejo de valores faltantes

# %%
# Porcemtaje de nulos por columnas antes de la imputación
print((df_life.isnull().sum() / len(df_life)) * 100)
# Out:
# country                            0.00
# year                               0.00
# status                             0.00
# life_expectancy                    0.00
# adult_mortality                    0.00
# infant_deaths                      0.00
# alcohol                            1.32
# percentage_expenditure             0.00
# hepatitis_b                       11.84
# measles                            0.00
# bmi                                0.56
# under_five_deaths                  0.00
# polio                              0.28
# total_expenditure                  1.94
# diphtheria                         0.28
# hiv/aids                           0.00
# gdp                               12.95
# population                        15.03
# thinness__1_19_years               0.56
# thinness_5_9_years                 0.56
# income_composition_of_resources    5.00
# schooling                          5.00
# dtype: float64

# %%
cols_to_impute_numeric = ['life_expectancy', 'adult_mortality', 'alcohol', 'gdp', 'schooling', 'bmi', 'income_composition_of_resources']
for col in cols_to_impute_numeric:
  df_life[col] = df_life.groupby('status')[col].transform(lambda x: x.fillna(x.median()))

# %%
# Para otras columnas con muchos nulos y que no son el focoprincipal, podrías eliminarlas o imputar con una constante si esnecesario
# Por simplicidad, nos enfocamos en las anteriores. Si alguna columna aún tiene nulos después de esto, rellenamos con la mediana global.
for col in cols_to_impute_numeric:
  if df_life[col].isnull().any():
    df_life[col].fillna(df_life[col].median(), inplace=True)

# %%
# Valores faltantes después de la imputación
df_life[cols_to_impute_numeric + ['status']].isnull().sum()
# Out:
# life_expectancy                    0
# adult_mortality                    0
# alcohol                            0
# gdp                                0
# schooling                          0
# bmi                                0
# income_composition_of_resources    0
# status                             0
# dtype: int64

# %% [markdown]
# ### Verificación de Tipos de Datos

# %%
# para saber que tipo de datos tengo
df_life.dtypes
# Out:
# country                             object
# year                                 int64
# status                              object
# life_expectancy                    float64
# adult_mortality                      int64
# infant_deaths                        int64
# alcohol                            float64
# percentage_expenditure              object
# hepatitis_b                        float64
# measles                              int64
# bmi                                float64
# under_five_deaths                    int64
# polio                              float64
# total_expenditure                  float64
# diphtheria                         float64
# hiv/aids                           float64
# gdp                                float64
# population                         float64
# thinness__1_19_years               float64
# thinness_5_9_years                 float64
# income_composition_of_resources    float64
# schooling                          float64
# ...

# %%
# Este codigo me da info extra pero al igual que dtypes me permite ver que tipo de datos tengo
df_life.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2880 entries, 0 to 2879
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country                          2880 non-null   object
#  1   year                             2880 non-null   int64
#  2   status                           2880 non-null   object
#  3   life_expectancy                  2880 non-null   float64
#  4   adult_mortality                  2880 non-null   int64
#  5   infant_deaths                    2880 non-null   int64
#  6   alcohol                          2880 non-null   float64
#  7   percentage_expenditure           2880 non-null   object
#  8   hepatitis_b                      2539 non-null   float64
#  9   measles                          2880 non-null   int64
#  10  bmi                              2880 non-null   float64
#  11  under_five_deaths                2880 non-null   int64
# ...

# %% [markdown]
# # Análisis Estadístico Descriptivo Univariado

# %% [markdown]
# ## Medidas estadísticas
#
# 1. Medidas de Tendencia Central: Calcula la media, mediana y moda.
# 2. Medidas de Dispersión: Calcula el rango, varianza y desviación estándar.
# 3. Medidas de Forma: Calcula la asimetría (skewness) y curtosis.

# %%
variables_num = ['life_expectancy', 'adult_mortality', 'gdp','schooling']

# %%
# Llamar la variable
variables_num
# Out:
# ['life_expectancy', 'adult_mortality', 'gdp', 'schooling']

# %%
# crear un dataframe nuevo y vacio para hacer los calculos de meen, media, moda y otros
stats_descriptive = pd.DataFrame()
stats_descriptive
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for var in variables_num:
  media = df_life[var].mean()
  mediana = df_life[var].median()
  # La moda puede tener múltiples valores, tomamos el primero
  moda = df_life[var].mode()[0] if not df_life[var].mode().empty else np.nan
  rango = df_life[var].max() - df_life[var].min()
  varianza = df_life[var].var()
  std_dev = df_life[var].std()
  asimetria = df_life[var].skew()
  curtosis_val = df_life[var].kurtosis() #Kurtosis de Fisher (exceso)
  stats_descriptive[var] = [media, mediana, moda, rango, varianza, std_dev, asimetria, curtosis_val]
  stats_descriptive.index = ['Media', 'Mediana', 'Moda', 'Rango', 'Varianza', 'Desv. Estándar', 'Asimetría', 'Curtosis']

# %%
stats_descriptive
# Out:
#                 life_expectancy  adult_mortality          gdp  schooling
# Media                     69.37           164.58      6964.10      12.11
# Mediana                   72.10           144.00      1413.54      12.30
# Moda                      73.00            12.00      1262.89      11.70
# Rango                     52.70           722.00    119171.06      20.70
# Varianza                  89.28         15220.71 180778734.94      10.35
# Desv. Estándar             9.45           123.37     13445.40       3.22
# Asimetría                 -0.66             1.22         3.42      -0.49
# Curtosis                  -0.15             1.93        14.34       0.63

# %%
# Tabla de Frecuencia - variable status
df_life['status'].value_counts()
# Out:
# status
# Developing    2368
# Developed      512
# Name: count, dtype: int64

# %%
# Tabla de Frecuencia (Porcentaje) para status
df_life['status'].value_counts(normalize=True) * 100
# Out:
# status
# Developing   82.22
# Developed    17.78
# Name: proportion, dtype: float64

# %% [markdown]
# **Pregunta de Interpretación 1:** Para la variable life_expectancy, compara la
# media y la mediana. ¿Qué te indica esta comparación sobre la simetría de su
# distribución? ¿Cómo se relaciona esto con el valor de asimetría calculado?

# %% [markdown]
# La media de life_expectancy (69.37) es menor que la mediana (72.10), lo que indica una distribución con asimetría negativa o sesgo hacia la izquierda. Esto sugiere que la mayoría de los países presentan valores relativamente altos de esperanza de vida, mientras que un grupo reducido con valores bajos desplaza la media hacia abajo.
#
# El valor de asimetría calculado (-0.66) confirma este patrón y sugiere un sesgo moderado. Aunque la distribución no es perfectamente normal, el nivel de asimetría aún conserva una forma cercana a la campana de normalidad. Este resultado evidencia la importancia de complementar la media con otras métricas como la mediana, el rango y la asimetría, ya que el promedio por sí solo puede verse afectado por valores extremos y no representar completamente la distribución de los datos.

# %% [markdown]
# ## Visualización Univariada

# %%
# Histograma y KDE: Para la variable life_expectancy.
plt.figure(figsize=(10, 6))
sns.histplot(df_life['life_expectancy'], kde=True, bins=30)
plt.title('Distribución de la Esperanza de Vida')
plt.xlabel('Esperanza de Vida (años)')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Boxplot: Para la variable life_expectancy, y también separada por status.
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.boxplot(y=df_life['life_expectancy'])
plt.title('Boxplot de Esperanza de Vida (Global)')
plt.ylabel('Esperanza de Vida (años)')
plt.subplot(1, 2, 2)
sns.boxplot(x='status', y='life_expectancy', data=df_life)
plt.title('Boxplot de Esperanza de Vida por Estatus del País')
plt.xlabel('Estatus del País')
plt.ylabel('Esperanza de Vida (años)')
plt.tight_layout()
plt.show()

# %%
# Gráfico de Barras: Para la frecuencia de la variable status.
plt.figure(figsize=(7, 5))
sns.countplot(x='status', data=df_life, palette='pastel')
plt.title('Frecuencia de Estatus de Países')
plt.xlabel('Estatus del País')
plt.ylabel('Número de Países')
plt.show()
# Out:
# /tmp/ipykernel_2157/3242303877.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='status', data=df_life, palette='pastel')

# %% [markdown]
# **Pregunta de Interpretación 2**: Observando el boxplot
# de life_expectancy por status, ¿qué diferencias principales notas entre
# países "Developed" y "Developing"? ¿Hay outliers evidentes?

# %% [markdown]
# El boxplot revela diferencias claras en la esperanza de vida entre países desarrollados y en desarrollo. Los países desarrollados presentan una mediana de esperanza de vida más alta y un rango intercuartílico más estrecho, lo que indica resultados de salud más consistentes y estables entre la población. En contraste, los países en desarrollo muestran una mayor variabilidad y una distribución más amplia, especialmente hacia valores bajos de esperanza de vida. Además, se observan varios valores atípicos inferiores en los países en desarrollo, posiblemente asociados a crisis humanitarias, conflictos o brotes de enfermedades. Por otro lado, los países desarrollados presentan menos outliers y distribuciones más compactas y homogéneas.

# %% [markdown]
# Análisis y Visualización Bivariada

# %%
# Scatter Plots:
# schooling vs life_expectancy.
# gdp vs life_expectancy (considera aplicar una transformación logarítmica al
# GDP si la escala es muy amplia).
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.scatterplot(x='schooling', y='life_expectancy', hue='status',
data=df_life, alpha=0.7)
plt.title('Esperanza de Vida vs. Escolaridad')
plt.xlabel('Años de Escolaridad Promedio')
plt.ylabel('Esperanza de Vida (años)')
plt.subplot(1, 2, 2)
# Aplicamos log a GDP para mejor visualización debido a la alta
# varianza
df_life_temp = df_life.copy() # Evitar modificar el df original
# para esta visualización
df_life_temp['log_gdp'] = np.log(df_life_temp['gdp'].replace(0,
np.nan)) # Reemplazar 0 con NaN antes de log
sns.scatterplot(x='log_gdp', y='life_expectancy', hue='status',
data=df_life_temp, alpha=0.7)
plt.title('Esperanza de Vida vs. Log(GDP per capita)')
plt.xlabel('Log(GDP per capita)')
plt.ylabel('Esperanza de Vida (años)')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Pregunta de Interpretación 3:** Según la matriz de correlación, ¿cuáles son las
# dos variables que muestran una correlación positiva más fuerte
# con life_expectancy? ¿Y cuál muestra la correlación negativa más fuerte?
# ¿Tiene sentido esto intuitivamente?

# %% [markdown]
# Según la matriz de correlación, las variables con la correlación positiva más fuerte respecto a life_expectancy son schooling (0.73) e income_composition_of_resources (0.71). Estos resultados sugieren que mayores niveles de educación y mejores condiciones socioeconómicas están asociados con una mayor esperanza de vida, probablemente debido a un mejor acceso a servicios de salud, nutrición y calidad de vida.
#
# Por otro lado, adult_mortality presenta la correlación negativa más fuerte (-0.70), indicando que mayores tasas de mortalidad adulta se relacionan directamente con una menor esperanza de vida. En conjunto, estas relaciones son consistentes desde una perspectiva demográfica y de salud pública, ya que reflejan el impacto del desarrollo social y las condiciones sanitarias sobre la longevidad de la población.

# %% [markdown]
# Matriz de Correlación (Heatmap): Para un subconjunto de variables numéricas
# (life_expectancy, adult_mortality, alcohol, gdp, schooling, bmi, income_re
# sources).

# %%
cols_for_corr = ['life_expectancy', 'adult_mortality', 'alcohol', 'gdp', 'schooling', 'bmi', 'income_composition_of_resources']
correlation_matrix = df_life[cols_for_corr].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm',fmt=".2f", linewidths=.5)
plt.title('Matriz de Correlación de Factores de Esperanza de Vida')
plt.show()

# %% [markdown]
# **Mini reporte de hallazgos y reflexión**

# %% [markdown]
# ### 1. Distribución de la Esperanza de Vida
#
# La esperanza de vida presenta una distribución sesgada a la izquierda, con una media de 69.37 años y una mediana de 72.10 años. Los países desarrollados muestran valores más altos y menor variabilidad en comparación con los países en desarrollo.
#
# ### 2. Factores Más Relacionados con la Esperanza de Vida
#
# Los factores con mayor correlación positiva fueron:
#
# * **Escolaridad (schooling)**: 0.73
# * **Composición de ingresos de recursos**: 0.71
#
# La correlación negativa más fuerte fue:
#
# * **Mortalidad adulta**: -0.70
#
# Esto indica que mayores niveles educativos y mejores condiciones socioeconómicas se asocian con mayor longevidad, mientras que una mayor mortalidad adulta reduce la esperanza de vida.
#
# ### 3. Patrones Observados
#
# Los análisis muestran una clara diferencia entre países desarrollados y en desarrollo. Los países desarrollados presentan mayor escolaridad, mayor PIB y mayor esperanza de vida. La transformación logarítmica del PIB permitió visualizar mejor estas relaciones debido a su alta variabilidad.
#
# ### 4. Implicaciones y Limitaciones
#
# Los resultados sugieren que fortalecer la educación, el desarrollo económico y reducir la mortalidad adulta son factores clave para mejorar la esperanza de vida.
#
# Limitaciones:
#
# * El análisis es correlacional, no causal.
# * La imputación de datos faltantes puede generar sesgos.
# * No se consideraron factores culturales, ambientales ni interacciones complejas entre variables.
