# %% [markdown]
# <a href="https://colab.research.google.com/github/polaya813/polaya813/blob/main/Entregable_Procesamiento_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importar librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
print("Librerías importadas correctamente.")
# Out:
# Librerías importadas correctamente.

# %% [markdown]
# Importar el archivo

# %%
df_ventas = pd.read_csv('market_data.csv')

# %%
print("Primeras 5 filas del DataFrame:")
print(df_ventas.head())
# Out:
# Primeras 5 filas del DataFrame:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
print("\nInformación general del DataFrame:")
df_ventas.info()
# Out:
# Información general del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# ...

# %%
print("\nEstadísticas descriptivas del DataFrame:")
print(df_ventas.describe(include='all'))
# Out:
# Estadísticas descriptivas del DataFrame:
#        Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# count             8523  7060.000000             8523      8523.000000
# unique            1559          NaN                5              NaN
# top              FDW13          NaN          Low Fat              NaN
# freq                10          NaN             5089              NaN
# mean               NaN    12.857645              NaN         0.066132
# std                NaN     4.643456              NaN         0.051598
# min                NaN     4.555000              NaN         0.000000
# 25%                NaN     8.773750              NaN         0.026989
# 50%                NaN    12.600000              NaN         0.053931
# 75%                NaN    16.850000              NaN         0.094585
# max                NaN    21.350000              NaN         0.328391
#
#                     Item_Type     Item_MRP Outlet_Identifier  \
# ...

# %%
print("\nValores faltantes por columna ANTES de la imputación:")
print(df_ventas.isnull().sum())
# Out:
# Valores faltantes por columna ANTES de la imputación:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# Imputar 'Item_Weight' con la mediana
mediana_item_weight = df_ventas['Item_Weight'].median()
df_ventas['Item_Weight'].fillna(mediana_item_weight, inplace=True)

print(f"\nValores NaN en 'Item_Weight' imputados con la mediana: {mediana_item_weight}")
# Out:
# Valores NaN en 'Item_Weight' imputados con la mediana: 12.6
# /tmp/ipykernel_6698/930955826.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ventas['Item_Weight'].fillna(mediana_item_weight, inplace=True)

# %% [markdown]
# Recibi este mensaje al correr el codigo anterior: /tmp/ipykernel_6698/930955826.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ventas['Item_Weight'].fillna(mediana_item_weight, inplace=True) asi que corri un codigo recomendado en copilot como sigue:

# %%
# Imputar 'Item_Weight' con la mediana
mediana_item_weight = df_ventas['Item_Weight'].median()

df_ventas['Item_Weight'] = df_ventas['Item_Weight'].fillna(mediana_item_weight)

print(f"\nValores NaN en 'Item_Weight' imputados con la mediana: {mediana_item_weight}")
# Out:
# Valores NaN en 'Item_Weight' imputados con la mediana: 12.6

# %%
# Imputar 'Outlet_Size' con la moda si es necesario
if df_ventas['Outlet_Size'].isnull().any():
    moda_outlet_size = df_ventas['Outlet_Size'].mode()[0]
    df_ventas['Outlet_Size'].fillna(moda_outlet_size, inplace=True)
    print(f"Valores NaN en 'Outlet_Size' imputados con la moda: {moda_outlet_size}")

print("\nValores faltantes por columna DESPUÉS de la imputación:")
print(df_ventas.isnull().sum())
# Out:
# Valores NaN en 'Outlet_Size' imputados con la moda: Medium
#
# Valores faltantes por columna DESPUÉS de la imputación:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64
# /tmp/ipykernel_6698/2251926422.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# igual paso con el codigo anterior: /tmp/ipykernel_6698/2251926422.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ventas['Outlet_Size'].fillna(moda_outlet_size, inplace=True)
